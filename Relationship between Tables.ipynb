# %% [markdown]
# # <font color=green>Relationship between Tables</font>
# ***
# In this notebook, we have two tables for us to apply data cleaning and the relationship between tables. <br>
# Let's get started by creating a table with movies.

# %%
import pandas as pd

data = {
    '#Number': ['M1001','M1002'],
    'Movie': ['Gremlins', 'The Last Samurai'],
    'Score': [5, 5],
    'Year': [1985, 2010]
}

df = pd.DataFrame(data)
df
# Out:
#   #Number             Movie  Score  Year
# 0   M1001          Gremlins      5  1985
# 1   M1002  The Last Samurai      5  2010

# %% [markdown]
# ## <font color=green>1 - Choose a column as key</font>
# ***
# Take a look at the index with the numbers 0 and 1 so far. What about to convert the column #Number as index?

# %%
df.set_index('#Number', inplace=True)
df
# Out:
#                     Movie  Score  Year
# #Number
# M1001            Gremlins      5  1985
# M1002    The Last Samurai      5  2010

# %% [markdown]
# ### <font color=green>1.1 - You have now how to find information based on the key</font>
# ***
# You have now how to find information based on the number of the movie.

# %%
df.loc['M1001']
# Out:
# Movie    Gremlins
# Score           5
# Year         1985
# Name: M1001, dtype: object

# %% [markdown]
# ### <font color=green>1.2 - Let's transform it into a Data Frame</font>
# ***
# You have this information like a list, now let's convert it into a dataframe.

# %%
df.loc[['M1001']]
# Out:
#             Movie  Score  Year
# #Number
# M1001    Gremlins      5  1985

# %% [markdown]
# ## <font color=green>2 - Creating a second table and different relationships</font>
# ***
# Let's create a second table and different relationships by using Pandas.

# %%
# Second Table
data2 = {
    '#Number': ['M1001', 'M1001', 'M1001', 'M1001', 'M1002', 'M1002', 'M1002', 'M1002', 'M1002', 'M1003'],
    'State': ['SP', 'RJ', 'MG', 'ES', 'BA', 'CE', 'PE', 'PI', 'RN', 'AM']
}

df2 = pd.DataFrame(data2)
df2
# Out:
#   #Number State
# 0   M1001    SP
# 1   M1001    RJ
# 2   M1001    MG
# 3   M1001    ES
# 4   M1002    BA
# 5   M1002    CE
# 6   M1002    PE
# 7   M1002    PI
# 8   M1002    RN
# 9   M1003    AM

# %% [markdown]
# ### <font color=green>2.1 - Choose a Key in common between tables - inner</font>
# ***
# We have the table df and df2, let's create a relationship based on the column '#Number'.
# Take a look at the movie M1003, it won't be in the new table:

# %%
merged_df = pd.merge(df, df2, on='#Number', how='inner')
merged_df
# Out:
#   #Number             Movie  Score  Year State
# 0   M1001          Gremlins      5  1985    SP
# 1   M1001          Gremlins      5  1985    RJ
# 2   M1001          Gremlins      5  1985    MG
# 3   M1001          Gremlins      5  1985    ES
# 4   M1002  The Last Samurai      5  2010    BA
# 5   M1002  The Last Samurai      5  2010    CE
# 6   M1002  The Last Samurai      5  2010    PE
# 7   M1002  The Last Samurai      5  2010    PI
# 8   M1002  The Last Samurai      5  2010    RN

# %% [markdown]
# ### <font color=green>2.2 - Column '#Number' as our index</font>
# ***
# We ever prefer to have a column that is a reference for all information, a kind of key, to be chosen as our index.

# %%
merged_df.set_index('#Number', inplace=True)
merged_df
# Out:
#                     Movie  Score  Year State
# #Number
# M1001            Gremlins      5  1985    SP
# M1001            Gremlins      5  1985    RJ
# M1001            Gremlins      5  1985    MG
# M1001            Gremlins      5  1985    ES
# M1002    The Last Samurai      5  2010    BA
# M1002    The Last Samurai      5  2010    CE
# M1002    The Last Samurai      5  2010    PE
# M1002    The Last Samurai      5  2010    PI
# M1002    The Last Samurai      5  2010    RN

# %% [markdown]
# ### <font color=green>2.3 - Outer Relationship - Right</font>
# ***
# We will choose the table df to be the most important in the relationship in a way where if it has records that the table df2 doesn't have, they will appear even if df2 be in NaN values.
# In this case, all movies in df are in df2. So, the result will be the same as the previous table.

# %%
merged_df = pd.merge(df2, df, on='#Number', how='right')
merged_df
# Out:
#   #Number State             Movie  Score  Year
# 0   M1001    SP          Gremlins      5  1985
# 1   M1001    RJ          Gremlins      5  1985
# 2   M1001    MG          Gremlins      5  1985
# 3   M1001    ES          Gremlins      5  1985
# 4   M1002    BA  The Last Samurai      5  2010
# 5   M1002    CE  The Last Samurai      5  2010
# 6   M1002    PE  The Last Samurai      5  2010
# 7   M1002    PI  The Last Samurai      5  2010
# 8   M1002    RN  The Last Samurai      5  2010

# %% [markdown]
# ### <font color=green>2.4 - Outer Relationship - Left</font>
# ***
# We will choose the table df2 to be the most important in the relationship in a way where if it has records that the table df doesn't have, they will appear even if df be in NaN values.

# %%
# Define the highlight function
def highlight_row(row):
    return ['background-color: yellow' if pd.isnull(value) else '' for value in row]

# %%
merged_df = pd.merge(df2, df, on='#Number', how='left')

# Apply the highlight function to the DataFrame
highlighted_df = merged_df.style.apply(highlight_row, axis=1)

# Display the highlighted DataFrame
highlighted_df
# Out:
# <style type="text/css">
# #T_588ef_row9_col2, #T_588ef_row9_col3, #T_588ef_row9_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_588ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_588ef_level0_col0" class="col_heading level0 col0" >#Number</th>
#       <th id="T_588ef_level0_col1" class="col_heading level0 col1" >State</th>
#       <th id="T_588ef_level0_col2" class="col_heading level0 col2" >Movie</th>
#       <th id="T_588ef_level0_col3" class="col_heading level0 col3" >Score</th>
#       <th id="T_588ef_level0_col4" class="col_heading level0 col4" >Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_588ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_588ef_row0_col0" class="data row0 col0" >M1001</td>
#       <td id="T_588ef_row0_col1" class="data row0 col1" >SP</td>
#       <td id="T_588ef_row0_col2" class="data row0 col2" >Gremlins</td>
#       <td id="T_588ef_row0_col3" class="data row0 col3" >5.000000</td>
#       <td id="T_588ef_row0_col4" class="data row0 col4" >1985.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_588ef_row1_col0" class="data row1 col0" >M1001</td>
#       <td id="T_588ef_row1_col1" class="data row1 col1" >RJ</td>
#       <td id="T_588ef_row1_col2" class="data row1 col2" >Gremlins</td>
#       <td id="T_588ef_row1_col3" class="data row1 col3" >5.000000</td>
#       <td id="T_588ef_row1_col4" class="data row1 col4" >1985.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_588ef_row2_col0" class="data row2 col0" >M1001</td>
#       <td id="T_588ef_row2_col1" class="data row2 col1" >MG</td>
#       <td id="T_588ef_row2_col2" class="data row2 col2" >Gremlins</td>
#       <td id="T_588ef_row2_col3" class="data row2 col3" >5.000000</td>
#       <td id="T_588ef_row2_col4" class="data row2 col4" >1985.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_588ef_row3_col0" class="data row3 col0" >M1001</td>
#       <td id="T_588ef_row3_col1" class="data row3 col1" >ES</td>
#       <td id="T_588ef_row3_col2" class="data row3 col2" >Gremlins</td>
#       <td id="T_588ef_row3_col3" class="data row3 col3" >5.000000</td>
#       <td id="T_588ef_row3_col4" class="data row3 col4" >1985.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_588ef_row4_col0" class="data row4 col0" >M1002</td>
#       <td id="T_588ef_row4_col1" class="data row4 col1" >BA</td>
#       <td id="T_588ef_row4_col2" class="data row4 col2" >The Last Samurai</td>
#       <td id="T_588ef_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_588ef_row4_col4" class="data row4 col4" >2010.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_588ef_row5_col0" class="data row5 col0" >M1002</td>
#       <td id="T_588ef_row5_col1" class="data row5 col1" >CE</td>
#       <td id="T_588ef_row5_col2" class="data row5 col2" >The Last Samurai</td>
#       <td id="T_588ef_row5_col3" class="data row5 col3" >5.000000</td>
#       <td id="T_588ef_row5_col4" class="data row5 col4" >2010.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_588ef_row6_col0" class="data row6 col0" >M1002</td>
#       <td id="T_588ef_row6_col1" class="data row6 col1" >PE</td>
#       <td id="T_588ef_row6_col2" class="data row6 col2" >The Last Samurai</td>
#       <td id="T_588ef_row6_col3" class="data row6 col3" >5.000000</td>
#       <td id="T_588ef_row6_col4" class="data row6 col4" >2010.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_588ef_row7_col0" class="data row7 col0" >M1002</td>
#       <td id="T_588ef_row7_col1" class="data row7 col1" >PI</td>
#       <td id="T_588ef_row7_col2" class="data row7 col2" >The Last Samurai</td>
#       <td id="T_588ef_row7_col3" class="data row7 col3" >5.000000</td>
#       <td id="T_588ef_row7_col4" class="data row7 col4" >2010.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_588ef_row8_col0" class="data row8 col0" >M1002</td>
#       <td id="T_588ef_row8_col1" class="data row8 col1" >RN</td>
#       <td id="T_588ef_row8_col2" class="data row8 col2" >The Last Samurai</td>
#       <td id="T_588ef_row8_col3" class="data row8 col3" >5.000000</td>
#       <td id="T_588ef_row8_col4" class="data row8 col4" >2010.000000</td>
#     </tr>
#     <tr>
#       <th id="T_588ef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_588ef_row9_col0" class="data row9 col0" >M1003</td>
#       <td id="T_588ef_row9_col1" class="data row9 col1" >AM</td>
#       <td id="T_588ef_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_588ef_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_588ef_row9_col4" class="data row9 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>
