# %% [markdown]
# # <font color=green>Working with Proportions</font>
# ***
# Suddenly you need to highlight a proportion as a way to generate some insight.

# %% [markdown]
# ***
# ## <font color=green>1 - Let's create a table</font>
# ***

# %%
import pandas as pd

data = {
    'Code': ['M1', 'M2', 'M3', 'M4', 'M5', 'M6'],
    'Heroe': ['Captain American', 'Hulk', 'Wolverine', 'Dr Strange', 'Spider Man', 'Hobbit'],
    'Score': [5, 3, 5, 5, 1, 5]
}

df = pd.DataFrame(data)
df
# Out:
#   Code             Heroe  Score
# 0   M1  Captain American      5
# 1   M2              Hulk      3
# 2   M3         Wolverine      5
# 3   M4        Dr Strange      5
# 4   M5        Spider Man      1
# 5   M6            Hobbit      5

# %% [markdown]
# ***
# ## <font color=green>2 - What about to create a view of proportions?</font>
# ***

# %%
# Calculate the proportion
proportion = df['Score']/df['Score'].sum()
proportion
# Out:
# 0    0.208333
# 1    0.125000
# 2    0.208333
# 3    0.208333
# 4    0.041667
# 5    0.208333
# Name: Score, dtype: float64

# %% [markdown]
# ***
# ## <font color=green>3 - We need to create a new column in our table</font>
# ***

# %%
df['%'] = proportion
df
# Out:
#   Code             Heroe  Score         %
# 0   M1  Captain American      5  0.208333
# 1   M2              Hulk      3  0.125000
# 2   M3         Wolverine      5  0.208333
# 3   M4        Dr Strange      5  0.208333
# 4   M5        Spider Man      1  0.041667
# 5   M6            Hobbit      5  0.208333

# %% [markdown]
# ***
# ## <font color=green>4 - Let's order our table</font>
# ***

# %%
df.sort_values('%')
# Out:
#   Code             Heroe  Score         %
# 4   M5        Spider Man      1  0.041667
# 1   M2              Hulk      3  0.125000
# 0   M1  Captain American      5  0.208333
# 2   M3         Wolverine      5  0.208333
# 3   M4        Dr Strange      5  0.208333
# 5   M6            Hobbit      5  0.208333

# %% [markdown]
# ***
# ## <font color=green>5 - Create a real key: Code</font>
# ***

# %%
df.set_index('Code', inplace=True)
df
# Out:
#                  Heroe  Score         %
# Code
# M1    Captain American      5  0.208333
# M2                Hulk      3  0.125000
# M3           Wolverine      5  0.208333
# M4          Dr Strange      5  0.208333
# M5          Spider Man      1  0.041667
# M6              Hobbit      5  0.208333

# %% [markdown]
# ***
# ## <font color=green>6 - What about highlighting our values?</font>
# ***

# %%
# Define the color function
def color_percentage(value):
    if value >= 0.20:
        color = 'green'
    elif value >= 0.10:
        color = 'orange'
    else:
        color = 'red'
    return 'background-color: %s' % color

# Apply the color function to the '%' column
styled_df = df.style.applymap(color_percentage, subset=['%'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_def44_row0_col2, #T_def44_row2_col2, #T_def44_row3_col2, #T_def44_row5_col2 {
#   background-color: green;
# }
# #T_def44_row1_col2 {
#   background-color: orange;
# }
# #T_def44_row4_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_def44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_def44_level0_col0" class="col_heading level0 col0" >Heroe</th>
#       <th id="T_def44_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_def44_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Code</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_def44_level0_row0" class="row_heading level0 row0" >M1</th>
#       <td id="T_def44_row0_col0" class="data row0 col0" >Captain American</td>
#       <td id="T_def44_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_def44_row0_col2" class="data row0 col2" >0.208333</td>
#     </tr>
#     <tr>
#       <th id="T_def44_level0_row1" class="row_heading level0 row1" >M2</th>
#       <td id="T_def44_row1_col0" class="data row1 col0" >Hulk</td>
#       <td id="T_def44_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_def44_row1_col2" class="data row1 col2" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_def44_level0_row2" class="row_heading level0 row2" >M3</th>
#       <td id="T_def44_row2_col0" class="data row2 col0" >Wolverine</td>
#       <td id="T_def44_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_def44_row2_col2" class="data row2 col2" >0.208333</td>
#     </tr>
#     <tr>
#       <th id="T_def44_level0_row3" class="row_heading level0 row3" >M4</th>
#       <td id="T_def44_row3_col0" class="data row3 col0" >Dr Strange</td>
#       <td id="T_def44_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_def44_row3_col2" class="data row3 col2" >0.208333</td>
#     </tr>
#     <tr>
#       <th id="T_def44_level0_row4" class="row_heading level0 row4" >M5</th>
#       <td id="T_def44_row4_col0" class="data row4 col0" >Spider Man</td>
#       <td id="T_def44_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_def44_row4_col2" class="data row4 col2" >0.041667</td>
#     </tr>
#     <tr>
#       <th id="T_def44_level0_row5" class="row_heading level0 row5" >M6</th>
#       <td id="T_def44_row5_col0" class="data row5 col0" >Hobbit</td>
#       <td id="T_def44_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_def44_row5_col2" class="data row5 col2" >0.208333</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***
# ## <font color=green>7 - We need to proportion the colors too, different colors are not essential in this case</font>
# ***

# %%
df.style.format({'%' : '{:.2%}'}) \
                        .bar(subset='%', vmin=0.05, color='lightblue')
# Out:
# <style type="text/css">
# #T_e7244_row0_col2, #T_e7244_row2_col2, #T_e7244_row3_col2, #T_e7244_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_e7244_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 47.4%, transparent 47.4%);
# }
# #T_e7244_row4_col2 {
#   width: 10em;
# }
# </style>
# <table id="T_e7244">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7244_level0_col0" class="col_heading level0 col0" >Heroe</th>
#       <th id="T_e7244_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_e7244_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Code</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7244_level0_row0" class="row_heading level0 row0" >M1</th>
#       <td id="T_e7244_row0_col0" class="data row0 col0" >Captain American</td>
#       <td id="T_e7244_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_e7244_row0_col2" class="data row0 col2" >20.83%</td>
#     </tr>
#     <tr>
#       <th id="T_e7244_level0_row1" class="row_heading level0 row1" >M2</th>
#       <td id="T_e7244_row1_col0" class="data row1 col0" >Hulk</td>
#       <td id="T_e7244_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_e7244_row1_col2" class="data row1 col2" >12.50%</td>
#     </tr>
#     <tr>
#       <th id="T_e7244_level0_row2" class="row_heading level0 row2" >M3</th>
#       <td id="T_e7244_row2_col0" class="data row2 col0" >Wolverine</td>
#       <td id="T_e7244_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_e7244_row2_col2" class="data row2 col2" >20.83%</td>
#     </tr>
#     <tr>
#       <th id="T_e7244_level0_row3" class="row_heading level0 row3" >M4</th>
#       <td id="T_e7244_row3_col0" class="data row3 col0" >Dr Strange</td>
#       <td id="T_e7244_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_e7244_row3_col2" class="data row3 col2" >20.83%</td>
#     </tr>
#     <tr>
#       <th id="T_e7244_level0_row4" class="row_heading level0 row4" >M5</th>
#       <td id="T_e7244_row4_col0" class="data row4 col0" >Spider Man</td>
#       <td id="T_e7244_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_e7244_row4_col2" class="data row4 col2" >4.17%</td>
#     </tr>
#     <tr>
#       <th id="T_e7244_level0_row5" class="row_heading level0 row5" >M6</th>
#       <td id="T_e7244_row5_col0" class="data row5 col0" >Hobbit</td>
#       <td id="T_e7244_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_e7244_row5_col2" class="data row5 col2" >20.83%</td>
#     </tr>
#   </tbody>
# </table>
